# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
house_train = pd.read_csv("train.csv")
house_test = pd.read_csv("test.csv")

# %% [markdown]
# # Preliminary Data understanding

# %%
house_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
house_test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
house_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
house_train.shape
# Out:
# (1460, 81)

# %%
#target variable = SalePrice

# %%
#null value analysis
house_train.isna().sum()[house_train.isna().sum()>0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
#As per prem analysis dropping columns
def drop_columns(list,dataset):
    dataset.drop(columns=list,inplace=True)

# %%
drop_columns(['LotFrontage','Alley','FireplaceQu','PoolQC','Fence','MiscFeature','Id'],house_train)

# %%
house_train.isna().sum()[house_train.isna().sum()>0]
# Out:
# MasVnrType       8
# MasVnrArea       8
# BsmtQual        37
# BsmtCond        37
# BsmtExposure    38
# BsmtFinType1    37
# BsmtFinType2    38
# Electrical       1
# GarageType      81
# GarageYrBlt     81
# GarageFinish    81
# GarageQual      81
# GarageCond      81
# dtype: int64

# %%
house_train.MasVnrType.value_counts()
# Out:
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64

# %%
#as of now we are dropping all the null values
house_train = house_train.dropna()

# %%
house_train.isna().sum()[house_train.isna().sum()>0]
# Out:
# Series([], dtype: int64)

# %%
house_train.shape
# Out:
# (1338, 74)

# %%
# we lost (1460-1338)/1460 = 8% data which is not significant

# %%
house_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1338 entries, 0 to 1459
# Data columns (total 74 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1338 non-null   int64
#  1   MSZoning       1338 non-null   object
#  2   LotArea        1338 non-null   int64
#  3   Street         1338 non-null   object
#  4   LotShape       1338 non-null   object
#  5   LandContour    1338 non-null   object
#  6   Utilities      1338 non-null   object
#  7   LotConfig      1338 non-null   object
#  8   LandSlope      1338 non-null   object
#  9   Neighborhood   1338 non-null   object
#  10  Condition1     1338 non-null   object
#  11  Condition2     1338 non-null   object
#  12  BldgType       1338 non-null   object
#  13  HouseStyle     1338 non-null   object
#  14  OverallQual    1338 non-null   int64
#  15  OverallCond    1338 non-null   int64
#  16  YearBuilt      1338 non-null   int64
# ...

# %%
numeric_index = house_train.dtypes[((house_train.dtypes == "int64") | (house_train.dtypes == "float64"))].index
# Out:
#                MSSubClass   LotArea  OverallQual  OverallCond  YearBuilt  \
# MSSubClass       1.000000 -0.134158     0.051690    -0.098153   0.056456
# LotArea         -0.134158  1.000000     0.090451     0.001415  -0.005022
# OverallQual      0.051690  0.090451     1.000000    -0.163080   0.570668
# OverallCond     -0.098153  0.001415    -0.163080     1.000000  -0.417330
# YearBuilt        0.056456 -0.005022     0.570668    -0.417330   1.000000
# YearRemodAdd     0.038513  0.001681     0.549460     0.035076   0.617156
# MasVnrArea       0.031333  0.096727     0.401175    -0.141080   0.299410
# BsmtFinSF1      -0.069053  0.210148     0.197441    -0.060068   0.224264
# BsmtFinSF2      -0.079329  0.110493    -0.086014     0.035698  -0.070403
# BsmtUnfSF       -0.141025 -0.014589     0.292940    -0.161038   0.147762
# TotalBsmtSF     -0.263613  0.267188     0.505897    -0.228020   0.385146
# 1stFlrSF        -0.258787  0.288502     0.481978    -0.144066   0.263585
# ...

# %%
plt.figure(figsize=(20,8))
sns.heatmap(house_train[numeric_index].corr(), cmap='Greens')

# %%
house_train.OverallQual
# Out:
# 0       7
# 1       6
# 2       7
# 3       7
# 4       8
#        ..
# 1455    6
# 1456    6
# 1457    7
# 1458    5
# 1459    5
# Name: OverallQual, Length: 1338, dtype: int64
